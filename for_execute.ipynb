# %%
! pip list
# Out:
# Package              Version
# -------------------- ---------
# anyio                3.4.0
# appnope              0.1.2
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asgiref              3.4.1
# attrs                21.4.0
# Babel                2.9.1
# backcall             0.2.0
# backports.zoneinfo   0.2.1
# bleach               4.1.0
# certifi              2021.5.30
# cffi                 1.15.0
# charset-normalizer   2.0.10
# click                8.0.3
# debugpy              1.5.1
# decorator            5.1.0
# defusedxml           0.7.1
# Django               4.0.1
# entrypoints          0.3
# Flask                2.0.2
# gunicorn             20.1.0
# idna                 3.3
# importlib-resources  5.4.0
# ipykernel            6.6.1
# ipython              7.31.0
# ipython-genutils     0.2.0
# itsdangerous         2.0.1
# jedi                 0.18.1
# Jinja2               3.0.3
# json5                0.9.6
# jsonschema           4.3.3
# jupyter-client       7.1.0
# ...

# %%
conda list
# Out:
# # packages in environment at /Users/tomokiiijima/miniforge3/envs/django_env_py38:
# #
# # Name                    Version                   Build  Channel
# anyio                     3.4.0                    pypi_0    pypi
# appnope                   0.1.2                    pypi_0    pypi
# argon2-cffi               21.3.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# asgiref                   3.4.1                    pypi_0    pypi
# attrs                     21.4.0                   pypi_0    pypi
# babel                     2.9.1                    pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# backports-zoneinfo        0.2.1                    pypi_0    pypi
# bleach                    4.1.0                    pypi_0    pypi
# ca-certificates           2021.10.26           hca03da5_2
# certifi                   2021.5.30        py38hca03da5_1
# ...
